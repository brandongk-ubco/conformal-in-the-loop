# %%
pip install avalanche-lib==0.5

# %%
from torch.utils.data import Subset
from avalanche.benchmarks.classic.ccifar100 import SplitCIFAR100
import numpy as np

def create_imbalanced_subset(dataset, class_counts):
    """Create an imbalanced subset of the dataset given class counts."""
    indices_per_class = {label: [] for label in range(100)}


    for idx in range(len(dataset)):
        label = dataset.targets[idx] if hasattr(dataset, 'targets') else dataset[idx][1]
        indices_per_class[label].append(idx)


    selected_indices = []
    for class_label, count in class_counts.items():
        available_count = len(indices_per_class[class_label])
        selected_count = min(count, available_count)
        selected_indices.extend(np.random.choice(indices_per_class[class_label], selected_count, replace=False))

    return np.array(selected_indices)


num_phases = 10
initial_count = 500 
decay_factor = 0.7


phase_class_counts = []
for i in range(num_phases):
    count = int(initial_count * (decay_factor ** i)) 
    class_counts = {label: count for label in range(100)}
    phase_class_counts.append(class_counts)


scenario = SplitCIFAR100(n_experiences=num_phases)


imbalanced_scenarios = []
for exp_id in range(num_phases):
    train_dataset = scenario.train_stream[exp_id].dataset
    counts = phase_class_counts[exp_id]


    selected_indices = create_imbalanced_subset(train_dataset, counts)
    imbalanced_train_subset = Subset(train_dataset, selected_indices)


    imbalanced_scenarios.append(imbalanced_train_subset)


    print(f"Phase {exp_id + 1}: Number of samples = {len(imbalanced_train_subset)}")

# %%
from torch.utils.data import Subset
from avalanche.benchmarks.classic.ccifar100 import SplitCIFAR100
import numpy as np

def create_imbalanced_subset(dataset, class_counts):
    indices_per_class = {label: [] for label in range(100)}
    
    for idx in range(len(dataset)):
        label = dataset.targets[idx] if hasattr(dataset, 'targets') else dataset[idx][1]
        indices_per_class[label].append(idx)

    selected_indices = []
    for class_label, count in class_counts.items():
        available_count = len(indices_per_class[class_label])
        selected_count = min(count, available_count)
        selected_indices.extend(np.random.choice(indices_per_class[class_label], selected_count, replace=False))

    return np.array(selected_indices)

num_phases = 10
classes_per_phase = 100 // num_phases
initial_count = 500
decay_factor = 0.7

phase_class_counts = []
phase_classes = []

for i in range(num_phases):
    start_class = i * classes_per_phase
    end_class = start_class + classes_per_phase
    current_classes = list(range(start_class, end_class))
    phase_classes.append(current_classes)
    
    count = int(initial_count * (decay_factor ** i))
    class_counts = {label: count for label in current_classes}
    phase_class_counts.append(class_counts)

scenario = SplitCIFAR100(n_experiences=num_phases, fixed_class_order=list(range(100)))

imbalanced_scenarios = []
for exp_id in range(num_phases):
    train_dataset = scenario.train_stream[exp_id].dataset
    counts = phase_class_counts[exp_id]

    selected_indices = create_imbalanced_subset(train_dataset, counts)
    imbalanced_train_subset = Subset(train_dataset, selected_indices)

    imbalanced_scenarios.append(imbalanced_train_subset)

    print(f"Phase {exp_id + 1}: Classes = {phase_classes[exp_id]}, Number of samples = {len(imbalanced_train_subset)}")

# %%
pip install pytorchcv==0.0.67

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.models import resnet18
from torchvision import transforms
from torch.utils.data import Subset
from avalanche.benchmarks.classic import SplitCIFAR100
from avalanche.training.supervised import EWC
from avalanche.training.plugins import EvaluationPlugin
from avalanche.evaluation.metrics import accuracy_metrics, loss_metrics
from avalanche.logging import InteractiveLogger

# Step 1: Define a feature extractor using pretrained ResNet18 with fixed weights
class FixedFeatureExtractor(nn.Module):
    def __init__(self, pretrained=True):
        super(FixedFeatureExtractor, self).__init__()
        resnet = resnet18(pretrained=pretrained)
        self.features = nn.Sequential(*list(resnet.children())[:-1])  # Remove the final classification layer
        for param in self.features.parameters():
            param.requires_grad = False  # Freeze the feature extractor

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)  # Flatten the output to [batch_size, 512]
        return x

# Step 2: Define a model that combines the fixed feature extractor with a trainable classification head
class FeatureExtractorWithHead(nn.Module):
    def __init__(self, num_classes=100):
        super(FeatureExtractorWithHead, self).__init__()
        self.feature_extractor = FixedFeatureExtractor()
        self.classifier = nn.Linear(512, num_classes)  # ResNet18 outputs 512-dimensional features

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.classifier(x)
        return x

# Step 3: Prepare the CIFAR-100 benchmark split into 10 phases with resizing transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to fit ResNet18's expected input size
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))  # CIFAR-100 normalization values
])

benchmark = SplitCIFAR100(n_experiences=10, fixed_class_order=list(range(100)), train_transform=transform, eval_transform=transform)

# Step 4: Initialize the model, optimizer, criterion, and EWC strategy
model = FeatureExtractorWithHead(num_classes=benchmark.n_classes)
optimizer = optim.SGD(model.classifier.parameters(), lr=0.01, momentum=0.9)  # Only train the classifier
criterion = nn.CrossEntropyLoss()

# Step 5: Set up evaluation metrics and logging
interactive_logger = InteractiveLogger()
evaluation_plugin = EvaluationPlugin(
    accuracy_metrics(epoch=True, stream=True),
    loss_metrics(epoch=True, stream=True),
    loggers=[interactive_logger]
)

# Step 6: Initialize EWC strategy for continual learning
ewc_lambda = 0.001  # Regularization strength for EWC
strategy = EWC(
    model, optimizer, criterion,
    ewc_lambda=ewc_lambda,
    train_epochs=5,  # Number of training epochs for each phase
    eval_every=1,  # Evaluate after each epoch
    plugins=[evaluation_plugin]
)

# Step 7: Training loop over the split CIFAR-100 benchmark
for experience in benchmark.train_stream:
    print(f"Training on phase {experience.current_experience + 1}")
    strategy.train(experience)
    strategy.eval(benchmark.test_stream)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training on phase 1
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:06<00:00, 75.72it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:06<00:00, 75.72it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 4.8253
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.0032
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 4.8253
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0032
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 4.8253
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0032
# 100%|██████████| 5000/5000 [01:16<00:00, 65.32it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8641
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1034
# 100%|██████████| 5000/5000 [01:16<00:00, 65.32it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8641
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1034
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:07<00:00, 74.32it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:07<00:00, 74.32it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 15.0493
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.3448
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 15.0493
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3448
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 15.0493
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3448
# 100%|██████████| 5000/5000 [01:17<00:00, 64.77it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.9927
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1176
# 100%|██████████| 5000/5000 [01:17<00:00, 64.77it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.9927
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1176
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:08<00:00, 73.37it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:08<00:00, 73.37it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 22.1914
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.3350
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.1914
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3350
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.1914
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3350
# 100%|██████████| 5000/5000 [01:16<00:00, 65.20it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.5962
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1240
# 100%|██████████| 5000/5000 [01:16<00:00, 65.20it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.5962
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1240
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:06<00:00, 75.38it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:06<00:00, 75.38it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 12.8439
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.4554
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 12.8439
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4554
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 12.8439
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4554
#   0%|          | 0/5000 [13:54<?, ?it/s]
#   0%|          | 0/5000 [13:54<?, ?it/s]
#   0%|          | 0/5000 [09:49<?, ?it/s]
#   0%|          | 0/5000 [09:49<?, ?it/s]
# 100%|██████████| 5000/5000 [01:14<00:00, 67.26it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.6829
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1386
# 100%|██████████| 5000/5000 [01:14<00:00, 67.26it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.6829
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1386
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:04<00:00, 77.54it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:04<00:00, 77.54it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 22.8562
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.4152
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.8562
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4152
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.8562
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4152
# 100%|██████████| 5000/5000 [01:15<00:00, 66.56it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.0250
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1446
# 100%|██████████| 5000/5000 [01:15<00:00, 66.56it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.0250
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1446
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.28it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.28it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp000 = 33.0897
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.3604
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 33.0897
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3604
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 33.0897
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3604
# -- >> End of training phase << --
# -- >> End of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.27it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.28it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 30.7160
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3710
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.17it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.17it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 88.7037
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 76.98it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 76.98it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 87.9747
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.17it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.18it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 75.0000
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.01it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.02it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 81.6267
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.01it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.02it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 76.4936
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 6 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.25it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.26it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 74.7249
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 7 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.46it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.46it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 70.4282
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 8 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.87it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.87it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 94.9154
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 9 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.02it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.02it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp009 = 82.4266
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 76.3010
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0371
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 76.3010
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0371
# Training on phase 2
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.19it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.19it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 87.2083
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 87.2083
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 87.2083
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# 100%|██████████| 5000/5000 [01:53<00:00, 44.23it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8942
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1050
# 100%|██████████| 5000/5000 [01:53<00:00, 44.23it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8942
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1050
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.54it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.54it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 30.7548
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.1706
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 30.7548
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1706
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 30.7548
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1706
# 100%|██████████| 5000/5000 [01:55<00:00, 43.31it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.7243
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1140
# 100%|██████████| 5000/5000 [01:55<00:00, 43.31it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.7243
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1140
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:10<00:00, 70.57it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:10<00:00, 70.57it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 22.2430
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.2566
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.2430
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2566
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.2430
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2566
# 100%|██████████| 5000/5000 [02:00<00:00, 41.52it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.5652
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1244
# 100%|██████████| 5000/5000 [02:00<00:00, 41.52it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.5652
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1244
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:10<00:00, 71.43it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:10<00:00, 71.43it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 24.0760
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.2804
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 24.0760
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2804
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 24.0760
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2804
# 100%|██████████| 5000/5000 [01:59<00:00, 41.76it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.9914
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1398
# 100%|██████████| 5000/5000 [01:59<00:00, 41.76it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.9914
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1398
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:10<00:00, 71.10it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:10<00:00, 71.10it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 29.3460
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.3134
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 29.3460
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3134
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 29.3460
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3134
# 100%|██████████| 5000/5000 [02:00<00:00, 41.50it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.9839
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1510
# 100%|██████████| 5000/5000 [02:00<00:00, 41.50it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.9839
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1510
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 1 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:10<00:00, 70.98it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:10<00:00, 70.98it/s]
# > Eval on experience 1 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp001 = 22.9700
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp001 = 0.4098
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.9700
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4098
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 22.9700
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.4098
# -- >> End of training phase << --
# -- >> End of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 72.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 72.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 58.6187
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0780
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 72.50it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 72.50it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 23.1265
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.4010
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.22it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.22it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 109.9070
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.37it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.37it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 98.3882
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 78.08it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 78.08it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 101.7242
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.75it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.76it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 101.7589
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 6 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:12<00:00, 77.51it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:12<00:00, 77.51it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 104.8847
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 7 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.47it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.47it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 102.0120
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 8 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.92it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.93it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 116.9073
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 9 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.16it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.17it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp009 = 106.7230
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 92.4051
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0479
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 92.4051
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0479
# Training on phase 3
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:04<00:00, 77.22it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:04<00:00, 77.22it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 110.2086
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 110.2086
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 110.2086
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# 100%|██████████| 5000/5000 [03:27<00:00, 24.10it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 22.3805
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1080
# 100%|██████████| 5000/5000 [03:27<00:00, 24.10it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 22.3805
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1080
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:09<00:00, 72.12it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:09<00:00, 72.13it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 40.1351
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.0864
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 40.1351
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0864
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 40.1351
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0864
# 100%|██████████| 5000/5000 [03:21<00:00, 24.77it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.8749
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1200
# 100%|██████████| 5000/5000 [03:21<00:00, 24.77it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.8749
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1200
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.52it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.52it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 41.8558
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.1400
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 41.8558
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1400
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 41.8558
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1400
# 100%|██████████| 5000/5000 [03:16<00:00, 25.40it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.0572
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1256
# 100%|██████████| 5000/5000 [03:16<00:00, 25.40it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.0572
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1256
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.49it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.49it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 37.5514
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.1854
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 37.5514
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1854
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 37.5514
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.1854
# 100%|██████████| 5000/5000 [03:27<00:00, 24.09it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.7686
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1434
# 100%|██████████| 5000/5000 [03:27<00:00, 24.09it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 19.7686
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1434
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:09<00:00, 71.88it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:09<00:00, 71.88it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 29.9693
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.2944
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 29.9693
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2944
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 29.9693
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.2944
# 100%|██████████| 5000/5000 [03:22<00:00, 24.65it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.4126
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1542
# 100%|██████████| 5000/5000 [03:22<00:00, 24.65it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 20.4126
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1542
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 2 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.89it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.89it/s]
# > Eval on experience 2 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp002 = 30.5682
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp002 = 0.3274
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 30.5682
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3274
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 30.5682
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.3274
# -- >> End of training phase << --
# -- >> End of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.19it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.19it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 65.3723
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1180
# -- Starting eval on experience 1 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.97it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.98it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 46.3960
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.1660
# -- Starting eval on experience 2 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.59it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.59it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 30.9760
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.3480
# -- Starting eval on experience 3 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.66it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.66it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 106.6408
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.97it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.98it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 115.7009
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.68it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.68it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 112.5240
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 6 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.06it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.06it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp006 = 114.2171
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 7 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.76it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.76it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp007 = 110.2426
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 8 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 75.44it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 75.44it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp008 = 123.7677
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 9 (Task 0) from test stream --
# 100%|██████████| 1000/1000 [00:13<00:00, 76.73it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 100%|██████████| 1000/1000 [00:13<00:00, 76.73it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp009 = 116.4511
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 94.2288
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0632
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream/Task000 = 94.2288
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0632
# Training on phase 4
# -- >> Start of training phase << --
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 76.37it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 76.37it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp003 = 106.4699
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp003 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 106.4699
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 106.4699
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0000
# 100%|██████████| 5000/5000 [04:22<00:00, 19.08it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 23.3102
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1082
# 100%|██████████| 5000/5000 [04:22<00:00, 19.08it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 23.3102
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1082
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:06<00:00, 75.69it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:06<00:00, 75.69it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp003 = 61.9442
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp003 = 0.0888
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 61.9442
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0888
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 61.9442
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0888
# 100%|██████████| 5000/5000 [04:29<00:00, 18.56it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.1680
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1136
# 100%|██████████| 5000/5000 [04:29<00:00, 18.56it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.1680
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1136
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:09<00:00, 71.44it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:09<00:00, 71.44it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp003 = 42.8655
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp003 = 0.0816
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 42.8655
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0816
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 42.8655
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0816
# 100%|██████████| 5000/5000 [04:23<00:00, 18.95it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8251
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1174
# 100%|██████████| 5000/5000 [04:23<00:00, 18.95it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.8251
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1174
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from train stream --
# 100%|██████████| 5000/5000 [01:05<00:00, 75.85it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 100%|██████████| 5000/5000 [01:05<00:00, 75.85it/s]
# > Eval on experience 3 (Task 0) from train stream ended.
# 	Loss_Exp/eval_phase/train_stream/Task000/Exp003 = 43.5590
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp003 = 0.0868
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 43.5590
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0868
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/train_stream/Task000 = 43.5590
# 	Top1_Acc_Stream/eval_phase/train_stream/Task000 = 0.0868
# 100%|██████████| 5000/5000 [04:16<00:00, 19.52it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.1861
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1234
# 100%|██████████| 5000/5000 [04:16<00:00, 19.52it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 21.1861
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1234
# -- >> Start of eval phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 3 (Task 0) from train stream --
# 0it [00:00, ?it/s]-- Starting eval on experience 3 (Task 0) from train stream --
#  56%|█████▋    | 2825/5000 [00:39<00:32, 67.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 74
#      72 for experience in benchmark.train_stream:
#      73     print(f"Training on phase {experience.current_experience + 1}")
# ---> 74     strategy.train(experience)
#      75     strategy.eval(benchmark.test_stream)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:211, in BaseSGDTemplate.train(self, experiences, eval_streams, **kwargs)
#     203 def train(
#     204     self,
#     205     experiences: Union[TDatasetExperience, Iterable[TDatasetExperience]],
#    (...)
#     209     **kwargs
#     210 ):
# --> 211     super().train(experiences, eval_streams, **kwargs)
#     212     return self.evaluator.get_last_metrics()
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base.py:163, in BaseTemplate.train(self, experiences, eval_streams, **kwargs)
#     161 for self.experience in experiences_list:
#     162     self._before_training_exp(**kwargs)
# --> 163     self._train_exp(self.experience, eval_streams, **kwargs)
#     164     self._after_training_exp(**kwargs)
#     165 self._after_training(**kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:338, in BaseSGDTemplate._train_exp(self, experience, eval_streams, **kwargs)
#     335     break
#     337 self.training_epoch(**kwargs)
# --> 338 self._after_training_epoch(**kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:519, in BaseSGDTemplate._after_training_epoch(self, **kwargs)
#     518 def _after_training_epoch(self, **kwargs):
# --> 519     trigger_plugins(self, "after_training_epoch", **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/utils.py:75, in trigger_plugins(strategy, event, **kwargs)
#      73 for p in strategy.plugins:
#      74     if hasattr(p, event):
# ---> 75         getattr(p, event)(strategy, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:639, in PeriodicEval.after_training_epoch(self, strategy, **kwargs)
#     636 """Periodic eval controlled by `self.eval_every` and
#     637 `self.peval_mode`."""
#     638 if self.peval_mode == "epoch":
# --> 639     self._maybe_peval(strategy, strategy.clock.train_exp_epochs, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:633, in PeriodicEval._maybe_peval(self, strategy, counter, **kwargs)
#     631 def _maybe_peval(self, strategy, counter, **kwargs):
#     632     if self.eval_every > 0 and counter % self.eval_every == 0:
# --> 633         self._peval(strategy, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:629, in PeriodicEval._peval(self, strategy, **kwargs)
#     627 def _peval(self, strategy, **kwargs):
#     628     for el in strategy._eval_streams:
# --> 629         strategy.eval(el, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:226, in BaseSGDTemplate.eval(self, exp_list, **kwargs)
#     214 @torch.no_grad()
#     215 def eval(self, exp_list: Union[CLExperience, CLStream], **kwargs):
#     216     """
#     217     Evaluate the current model on a series of experiences and
#     218     returns the last recorded value for each metric.
#    (...)
#     224         each metric name
#     225     """
# --> 226     super().eval(exp_list, **kwargs)
#     227     return self.evaluator.get_last_metrics()
#
# File /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base.py:212, in BaseTemplate.eval(self, experiences, **kwargs)
#     210 for self.experience in experiences_list:
#     211     self._before_eval_exp(**kwargs)
# --> 212     self._eval_exp(**kwargs)
#     213     self._after_eval_exp(**kwargs)
#     215 self._after_eval(**kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:230, in BaseSGDTemplate._eval_exp(self, **kwargs)
#     229 def _eval_exp(self, **kwargs):
# --> 230     self.eval_epoch(**kwargs)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/base_sgd.py:272, in BaseSGDTemplate.eval_epoch(self, **kwargs)
#     269 self._before_eval_iteration(**kwargs)
#     271 self._before_eval_forward(**kwargs)
# --> 272 self.mb_output = self.forward()
#     273 self._after_eval_forward(**kwargs)
#     274 self.loss = self.criterion()
#
# File ~/.local/lib/python3.12/site-packages/avalanche/training/templates/problem_type/supervised_problem.py:47, in SupervisedProblem.forward(self)
#      45 def forward(self):
#      46     """Compute the model's output given the current mini-batch."""
# ---> 47     return avalanche_forward(self.model, self.mb_x, self.mb_task_id)
#
# File ~/.local/lib/python3.12/site-packages/avalanche/models/utils.py:22, in avalanche_forward(model, x, task_labels)
#      20     return model(x, task_labels)
#      21 else:  # no task labels
# ---> 22     return model(x)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[8], line 35, in FeatureExtractorWithHead.forward(self, x)
#      34 def forward(self, x):
# ---> 35     x = self.feature_extractor(x)
#      36     x = self.classifier(x)
#      37     return x
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[8], line 23, in FixedFeatureExtractor.forward(self, x)
#      22 def forward(self, x):
# ---> 23     x = self.features(x)
#      24     x = torch.flatten(x, 1)  # Flatten the output to [batch_size, 512]
#      25     return x
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:164, in MaxPool2d.forward(self, input)
#     163 def forward(self, input: Tensor):
# --> 164     return F.max_pool2d(input, self.kernel_size, self.stride,
#     165                         self.padding, self.dilation, ceil_mode=self.ceil_mode,
#     166                         return_indices=self.return_indices)
#
# File /usr/local/lib/python3.12/dist-packages/torch/_jit_internal.py:503, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     501     return if_true(*args, **kwargs)
#     502 else:
# --> 503     return if_false(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py:796, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     794 if stride is None:
#     795     stride = torch.jit.annotate(List[int], [])
# --> 796 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:
#  56%|█████▋    | 2825/5000 [00:56<00:32, 67.48it/s]
